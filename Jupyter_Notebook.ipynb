# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Notebook Title

# %% [markdown]
# ## Introduction
#
# Welcome to my notebook! In this analysis, we will explore [topic] and delve into [objective]. Throughout the notebook, we'll examine [key points] and draw insights from the data.
#
# I hope you find this exploration insightful and enjoyable. Let's get started!

# %% [markdown]
# ## Data Science Languages
#
# 1. **Python:** Widely used for data analysis, machine learning, and scientific computing. Popular libraries include NumPy, Pandas, and scikit-learn.
#
# 2. **R:** Commonly used for statistical analysis and data visualization. R has a strong community for statistical computing.
#
# 3. **SQL:** Essential for working with relational databases, used to query and manipulate data.
#
# 4. **Julia:** Known for its speed and performance, Julia is used for numerical and scientific computing.
#
# 5. **Scala:** Often used with Apache Spark for big data processing. Combines functional programming with object-oriented programming.
#
# 6. **MATLAB:** Popular in academia and industry for numerical computing, data analysis, and visualization.
#
# 7. **Java:** Widely used for big data processing and development of scalable applications.
#
# 8. **JavaScript:** Useful for data visualization on the web, with libraries like D3.js and Chart.js.
#
# 9. **SAS:** A software suite for advanced analytics, business intelligence, and data management.
#
# 10. **Go (Golang):** Gaining popularity for its efficiency and simplicity, used in some data engineering tasks.
#
# Choose the language that best fits your project requirements and preferences.

# %% [markdown]
# ## Data Science Libraries in Python
#
# 1. **NumPy:** Fundamental package for numerical computing with Python.
#
# 2. **Pandas:** Data manipulation and analysis library, providing data structures like DataFrame.
#
# 3. **Matplotlib:** Comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# 4. **Seaborn:** Built on top of Matplotlib, Seaborn provides a high-level interface for drawing attractive and informative statistical graphics.
#
# 5. **Scikit-learn:** Simple and efficient tools for data mining and data analysis, particularly for machine learning.
#
# 6. **TensorFlow:** An open-source machine learning framework developed by Google for building and training deep learning models.
#
# 7. **PyTorch:** Another popular machine learning library, particularly well-suited for deep learning tasks.
#
# 8. **SciPy:** Open-source library used for mathematics, science, and engineering.
#
# 9. **Statsmodels:** Library for estimating and testing statistical models.
#
# 10. **NLTK (Natural Language Toolkit):** Library for working with human language data, including text processing and analysis.
#
# 11. **Beautiful Soup:** Library for pulling data out of HTML and XML files, particularly useful for web scraping.
#
# 12. **Keras:** High-level neural networks API, written in Python and capable of running on top of TensorFlow, CNTK, or Theano.
#
# These libraries form the foundation for many data science projects in Python, covering a wide range of tasks from data manipulation to machine learning and visualization.

# %% [markdown]
# ## Data Science Tools
#
# | Tool              | Description                                    |
# |-------------------|------------------------------------------------|
# | **Jupyter Notebooks** | Interactive web-based notebooks for data analysis and visualization. |
# | **RStudio**          | Integrated development environment (IDE) for R programming. |
# | **Anaconda**         | Distribution of Python and R programming languages for data science and machine learning. |
# | **Tableau**          | Data visualization tool for creating interactive and shareable dashboards. |
# | **Apache Spark**     | Open-source distributed computing system for big data processing. |
# | **Hadoop**           | Framework for distributed storage and processing of large data sets. |
# | **Docker**           | Platform for containerization, allowing for easy deployment and scaling of applications. |
# | **Git**              | Version control system for tracking changes in code and collaboration. |
# | **TensorBoard**      | Web-based tool for visualizing TensorFlow models and monitoring training. |
# | **Kaggle**           | Platform for data science competitions, datasets, and notebooks. |
# | **Airflow**          | Platform for orchestrating complex data workflows and data pipeline management. |
# | **Selenium**         | Web testing framework, often used for web scraping in data collection. |
#
# These tools play crucial roles in different aspects of the data science lifecycle, from data exploration and analysis to machine learning and deployment. Choose the tools that best suit your project requirements and workflow preferences.

# %% [markdown]
# ## Arithmetic Expression Examples
#
# Arithmetic expressions are fundamental in mathematics and programming, representing mathematical operations. In this section, we'll explore some common arithmetic expressions using basic operators.
#
# ### Basic Operators:
#
# - **Addition (+):** Adds two numbers.
# - **Subtraction (-):** Subtracts the right operand from the left operand.
# - **Multiplication (*):** Multiplies two numbers.
# - **Division (/):** Divides the left operand by the right operand.
# - **Modulus (%):** Returns the remainder of the division of the left operand by the right operand.
# - **Exponentiation (** or ^):** Raises the left operand to the power of the right operand.
#
# ### Examples:
#
# #### Addition:
# ```python
# result = 5 + 3
# # Output: 8

# %% [markdown]
# ## Multiplication and Addition in Python
#
# To perform multiplication and addition in Python, you can use the following code:
#
# ### Multiplication:
# ```python
# # Multiply two numbers
# result_multiply = 5 * 8
# print("Multiplication result:", result_multiply)

# %% [markdown]
# # Add two numbers
# result_addition = 10 + 7
# print("Addition result:", result_addition)

# %% [markdown]
# ## Convert Minutes to Hours in Python
#
# To convert minutes to hours in Python, you can use the following code:
#
# ```python
# # Function to convert minutes to hours
# def convert_minutes_to_hours(minutes):
#     hours = minutes / 60
#     return hours
#
# # Example usage
# minutes_value = 120
# hours_result = convert_minutes_to_hours(minutes_value)
#
# print(f"{minutes_value} minutes is equal to {hours_result:.2f} hours.")

# %% [markdown]
# ## Objectives
#
# 1. **Data Exploration:** Gain a comprehensive understanding of the dataset, examining key features, patterns, and potential outliers.
#
# 2. **Preprocessing:** Clean and prepare the data for analysis by handling missing values, encoding categorical variables, and scaling numerical features.
#
# 3. **Statistical Analysis:** Perform descriptive statistics and statistical tests to uncover insights into the data distribution and relationships.
#
# 4. **Data Visualization:** Create informative visualizations to represent data trends, patterns, and relationships for better interpretation.
#
# 5. **Model Building:** Develop machine learning models to make predictions or classifications based on the dataset.
#
# 6. **Model Evaluation:** Assess the performance of machine learning models using appropriate metrics, such as accuracy, precision, recall, and F1-score.
#
# 7. **Hyperparameter Tuning:** Optimize model performance by fine-tuning hyperparameters for better results.
#
# 8. **Interpretation:** Interpret the results of the analysis, providing insights and recommendations based on the findings.
#
# 9. **Documentation:** Document the entire data science process, including data exploration, preprocessing steps, model development, and evaluation.
#
# 10. **Communication:** Communicate findings effectively through presentations, visualizations, and reports to both technical and non-technical stakeholders.

# %% [markdown]
#     ## Author
#
# **[Naman]**
